# %% [markdown]
# <a href="https://colab.research.google.com/github/KimYunGyu2/ai/blob/main/%EC%95%88%EB%A9%B4%EC%9D%B8%EC%8B%9D2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Client ID      : jt0yx_7bSlkHKfQdHPHq
# Client Secret  : QeTdj81dtO


import os       # 운영체제 접근
import sys      # 시스템 접근
import requests # 웹 접근

client_id = "jt0yx_7bSlkHKfQdHPHq"
client_secret = "QeTdj81dtO"


url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
# url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식

files = {'image': open('1313.jpg', 'rb')}

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":259,"height":194},"faceCount":4},"faces":[{"roi":{"x":93,"y":41,"width":33,"height":33},"landmark":{"leftEye":{"x":104,"y":52},"rightEye":{"x":119,"y":50},"nose":{"x":116,"y":56},"leftMouth":{"x":105,"y":67},"rightMouth":{"x":120,"y":65}},"gender":{"value":"female","confidence":0.999885},"age":{"value":"52~56","confidence":0.852118},"emotion":{"value":"laugh","confidence":0.99999},"pose":{"value":"frontal_face","confidence":0.743609}},{"roi":{"x":151,"y":51,"width":38,"height":38},"landmark":null,"gender":{"value":"female","confidence":0.999947},"age":{"value":"30~34","confidence":0.848528},"emotion":{"value":"laugh","confidence":0.993793},"pose":{"value":"false_face","confidence":0.868299}},{"roi":{"x":121,"y":20,"width":38,"height":38},"landmark":{"leftEye":{"x":135,"y":31},"rightEye":{"x":151,"y":31},"nose":{"x":144,"y":41},"leftMouth":{"x":133,"y":49},"rightMouth":{"x":149,"y":50}},"gender":{"value":"male","confidence":0.999997},"age":{"value":"47~51","co
# ...

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 259, 'height': 194}, 'faceCount': 4}, 'faces': [{'roi': {'x': 93, 'y': 41, 'width': 33, 'height': 33}, 'landmark': {'leftEye': {'x': 104, 'y': 52}, 'rightEye': {'x': 119, 'y': 50}, 'nose': {'x': 116, 'y': 56}, 'leftMouth': {'x': 105, 'y': 67}, 'rightMouth': {'x': 120, 'y': 65}}, 'gender': {'value': 'female', 'confidence': 0.999885}, 'age': {'value': '52~56', 'confidence': 0.852118}, 'emotion': {'value': 'laugh', 'confidence': 0.99999}, 'pose': {'value': 'frontal_face', 'confidence': 0.743609}}, {'roi': {'x': 151, 'y': 51, 'width': 38, 'height': 38}, 'landmark': None, 'gender': {'value': 'female', 'confidence': 0.999947}, 'age': {'value': '30~34', 'confidence': 0.848528}, 'emotion': {'value': 'laugh', 'confidence': 0.993793}, 'pose': {'value': 'false_face', 'confidence': 0.868299}}, {'roi': {'x': 121, 'y': 20, 'width': 38, 'height': 38}, 'landmark': {'leftEye': {'x': 135, 'y': 31}, 'rightEye': {'x': 151, 'y': 31}, 'nose': {'x': 144, 'y': 41}, 'leftMouth': {
# ...

# %%
print(json.dumps(parsed, indent= 4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 259,
#             "height": 194
#         },
#         "faceCount": 4
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 93,
#                 "y": 41,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 104,
#                     "y": 52
#                 },
#                 "rightEye": {
#                     "x": 119,
#                     "y": 50
#                 },
#                 "nose": {
#                     "x": 116,
#                     "y": 56
#                 },
#                 "leftMouth": {
#                     "x": 105,
#                     "y": 67
#                 },
#                 "rightMouth": {
#                     "x": 120,
#                     "y": 65
#                 }
#             },
#             "gender": {
# ...

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
parsed['faces']
# Out:
# [{'age': {'confidence': 0.852118, 'value': '52~56'},
#   'emotion': {'confidence': 0.99999, 'value': 'laugh'},
#   'gender': {'confidence': 0.999885, 'value': 'female'},
#   'landmark': {'leftEye': {'x': 104, 'y': 52},
#    'leftMouth': {'x': 105, 'y': 67},
#    'nose': {'x': 116, 'y': 56},
#    'rightEye': {'x': 119, 'y': 50},
#    'rightMouth': {'x': 120, 'y': 65}},
#   'pose': {'confidence': 0.743609, 'value': 'frontal_face'},
#   'roi': {'height': 33, 'width': 33, 'x': 93, 'y': 41}},
#  {'age': {'confidence': 0.848528, 'value': '30~34'},
#   'emotion': {'confidence': 0.993793, 'value': 'laugh'},
#   'gender': {'confidence': 0.999947, 'value': 'female'},
#   'landmark': None,
#   'pose': {'confidence': 0.868299, 'value': 'false_face'},
#   'roi': {'height': 38, 'width': 38, 'x': 151, 'y': 51}},
#  {'age': {'confidence': 0.188188, 'value': '47~51'},
#   'emotion': {'confidence': 0.98923, 'value': 'smile'},
#   'gender': {'confidence': 0.999997, 'value': 'male'},
# ...

# %%
from typing import AsyncGenerator
import matplotlib.pyplot as plt      # 사진(그림) 관련 기본모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('1313.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))       # 사진을 표시할 액자와 사진 설정
ax.imshow(img)                 # 액자에 사진 삽입

x,y,w,h = parsed['faces'][0]['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
age, age_conf = parsed['faces'][0]['age'].values()
gender,gender_conf = parsed['faces'][0]['gender'].values()

re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') # 그 위치에 사각형을 표시 정보
anno = gender + ',' + age

plt.text(x,y+40, anno, color ='blue')
ax.add_patch(re_face)                     # 사진 수정

# %%
import matplotlib.pyplot as plt      # 사진(그림) 관련 기본모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches # 사진 수정 관련 모듈

img = mpimg.imread('1313.jpg') # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))       # 사진을 표시할 액자와 사진 설정
ax.imshow(img)                 # 액자에 사진 삽입

for i in range(0,4):
  x,y,w,h = parsed['faces'][i]['roi'].values()
  age, age_conf = parsed['faces'][i]['age'].values()
  gender,gender_conf = parsed['faces'][i]['gender'].values()

  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')
  anno = gender + ',' + age
  plt.text(x,y+h+5, anno, color ='blue')
  ax.add_patch(re_face)
